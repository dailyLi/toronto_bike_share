# %% [markdown]
# ## Data source
#
# https://open.toronto.ca/dataset/bike-share-toronto-ridership-data/

# %%
import numpy as np
import pandas as pd
import datetime
import time
import requests
import json
from geopy import distance

# %% [markdown]
# Load Jan 2021 dataset:

# %%
df01 = pd.read_csv("bike-share-ridership-2021-01.csv",encoding='cp1252')
df01.head()
# Out:
#     Trip Id  Trip  Duration  Start Station Id        Start Time  \
# 0  10644218            1315              7021  01/01/2021 00:04
# 1  10644220             396              7534  01/01/2021 00:07
# 2  10644221              86              7162  01/01/2021 00:10
# 3  10644222             741              7003  01/01/2021 00:10
# 4  10644223            2073              7562  01/01/2021 00:11
#
#                      Start Station Name  End Station Id          End Time  \
# 0                    Bay St / Albert St          7164.0  01/01/2021 00:26
# 1               Walnut Ave / Queen St W          7524.0  01/01/2021 00:13
# 2              Hayter St / Laplante Ave          7006.0  01/01/2021 00:11
# 3              Madison Ave / Bloor St W          7272.0  01/01/2021 00:22
# 4  Priscilla  Ave / Dundas St W - SMART          7562.0  01/01/2021 00:45
#
#                            End Station Name  Bike Id      User Type
# 0  Gould St / Yonge St (Ryerson University)   6795.0  Annual Member
# 1                               Lisgar Park   4176.0  Casual Member
# 2           Bay St / College St (East Side)   1814.0  Annual Member
# 3           Yonge St / Dundonald St - SMART    198.0  Casual Member
# 4      Priscilla  Ave / Dundas St W - SMART   6688.0  Casual Member

# %% [markdown]
# According to data dictionary:
#
# - Trip Id: Object ID, unique integer
# - Trip Duration: Duration of a trip in seconds
# - Start Station Id: ID of the station where the trip started (origin)
# - Start time: mm/dd/yyyy 00:00
# - Start Station Name
# - End Station Id: ID of the station where the trip ended (destination)
# - End Time
# - End Station Name
# - Bike Id
# - User type: The type of user that took the trip, member (annual pass holder) or casual (24 or 72 hour pass holders)

# %%
df01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86371 entries, 0 to 86370
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Trip Id             86371 non-null  int64
#  1   Trip  Duration      86371 non-null  int64
#  2   Start Station Id    86371 non-null  int64
#  3   Start Time          86371 non-null  object
#  4   Start Station Name  86069 non-null  object
#  5   End Station Id      86058 non-null  float64
#  6   End Time            86371 non-null  object
#  7   End Station Name    85759 non-null  object
#  8   Bike Id             86168 non-null  float64
#  9   User Type           86371 non-null  object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 6.6+ MB

# %% [markdown]
# Since the datasets are large, we decide to explore Jan 2021 data first, then apply the same workflow to other months, and finally combine 12 months together.
#
# ## Data Cleaning

# %% [markdown]
# ### Check missing values
#
# From the summary above, it shows null value in "End Station Name", but not all of them miss End Station Id, so we check the rows without End Station Id first

# %%
df01[df01["End Station Id"].isna()]
# Out:
#         Trip Id  Trip  Duration  Start Station Id        Start Time  \
# 333    10644662               0              7470  01/01/2021 09:41
# 1304   10645786               0              7063  01/01/2021 16:00
# 1335   10645823               0              7419  01/01/2021 16:10
# 1444   10645959               0              7281  01/01/2021 16:38
# 1878   10646666            1336              7203  01/02/2021 09:12
# ...         ...             ...               ...               ...
# 82325  10743730               0              7177  01/29/2021 20:23
# 83166  10744707               0              7040  01/30/2021 12:52
# 83260  10744806               0              7627  01/30/2021 13:18
# 83823  10745412               0              7518  01/30/2021 15:21
# 85293  10747166               0              7560  01/31/2021 12:10
#
#                                   Start Station Name  End Station Id  \
# 333                      York St / Lake Shore Blvd W             NaN
# 1304                       Queen's Park / Bloor St W             NaN
# 1335                           Bloor St W / Huron St             NaN
# 1444               Charles St W / Balmuto St - SMART             NaN
# 1878   Bathurst St/Queens Quay(Billy Bishop Airport)             NaN
# ...                                              ...             ...
# 82325                East Liberty St / Pirandello St             NaN
# 83166                        Euclid Ave / Bloor St W             NaN
# 83260                             Shaw St / Essex St             NaN
# 83823          Lake Shore Blvd W / Colborne Lodge Dr             NaN
# 85293            Glenwood Ave / Runnymede Rd - SMART             NaN
#
#                End Time End Station Name  Bike Id      User Type
# 333    01/01/2021 09:41              NaN   5761.0  Annual Member
# 1304   01/01/2021 16:00              NaN   6731.0  Annual Member
# 1335   01/01/2021 16:10              NaN   6835.0  Casual Member
# 1444   01/01/2021 16:38              NaN   5748.0  Annual Member
# 1878   01/02/2021 09:34              NaN   2598.0  Annual Member
# ...                 ...              ...      ...            ...
# 82325  01/29/2021 20:23              NaN   3878.0  Annual Member
# 83166  01/30/2021 12:52              NaN   1672.0  Casual Member
# 83260  01/30/2021 13:18              NaN   3262.0  Annual Member
# 83823  01/30/2021 15:21              NaN   1541.0  Annual Member
# 85293  01/31/2021 12:10              NaN   5339.0  Casual Member
#
# [313 rows x 10 columns]

# %% [markdown]
# Here we find entries that have Trip Duration = 0. These might be some errors or technical issues when the bikes were released.

# %%
df01[df01["Trip  Duration"] == 0]
# Out:
#         Trip Id  Trip  Duration  Start Station Id        Start Time  \
# 333    10644662               0              7470  01/01/2021 09:41
# 1304   10645786               0              7063  01/01/2021 16:00
# 1335   10645823               0              7419  01/01/2021 16:10
# 1444   10645959               0              7281  01/01/2021 16:38
# 1933   10646723               0              7072  01/02/2021 10:10
# ...         ...             ...               ...               ...
# 82862  10744378               0              7270  01/30/2021 10:44
# 83166  10744707               0              7040  01/30/2021 12:52
# 83260  10744806               0              7627  01/30/2021 13:18
# 83823  10745412               0              7518  01/30/2021 15:21
# 85293  10747166               0              7560  01/31/2021 12:10
#
#                           Start Station Name  End Station Id  \
# 333              York St / Lake Shore Blvd W             NaN
# 1304               Queen's Park / Bloor St W             NaN
# 1335                   Bloor St W / Huron St             NaN
# 1444       Charles St W / Balmuto St - SMART             NaN
# 1933                  Fleet St / Bathurst St          7569.0
# ...                                      ...             ...
# 82862        Church St / Dundas St E - SMART          7001.0
# 83166                Euclid Ave / Bloor St W             NaN
# 83260                     Shaw St / Essex St             NaN
# 83823  Lake Shore Blvd W / Colborne Lodge Dr             NaN
# 85293    Glenwood Ave / Runnymede Rd - SMART             NaN
#
#                End Time                 End Station Name  Bike Id  \
# 333    01/01/2021 09:41                              NaN   5761.0
# 1304   01/01/2021 16:00                              NaN   6731.0
# 1335   01/01/2021 16:10                              NaN   6835.0
# 1444   01/01/2021 16:38                              NaN   5748.0
# 1933   01/02/2021 10:10            Toronto Inukshuk Park   2306.0
# ...                 ...                              ...      ...
# 82862  01/30/2021 10:44  Lower Jarvis St / The Esplanade   1753.0
# 83166  01/30/2021 12:52                              NaN   1672.0
# 83260  01/30/2021 13:18                              NaN   3262.0
# 83823  01/30/2021 15:21                              NaN   1541.0
# 85293  01/31/2021 12:10                              NaN   5339.0
#
#            User Type
# 333    Annual Member
# 1304   Annual Member
# 1335   Casual Member
# 1444   Annual Member
# 1933   Annual Member
# ...              ...
# 82862  Annual Member
# 83166  Casual Member
# 83260  Annual Member
# 83823  Annual Member
# 85293  Casual Member
#
# [514 rows x 10 columns]

# %%
df01_v1 = df01[df01["Trip  Duration"] != 0]
df01_v1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85857 entries, 0 to 86370
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Trip Id             85857 non-null  int64
#  1   Trip  Duration      85857 non-null  int64
#  2   Start Station Id    85857 non-null  int64
#  3   Start Time          85857 non-null  object
#  4   Start Station Name  85555 non-null  object
#  5   End Station Id      85830 non-null  float64
#  6   End Time            85857 non-null  object
#  7   End Station Name    85533 non-null  object
#  8   Bike Id             85654 non-null  float64
#  9   User Type           85857 non-null  object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 7.2+ MB

# %%
df01_v1 = df01_v1[df01_v1["End Station Id"].notnull()]
df01_v1 = df01_v1[df01_v1["Bike Id"].notnull()]
df01_v1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85627 entries, 0 to 86370
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Trip Id             85627 non-null  int64
#  1   Trip  Duration      85627 non-null  int64
#  2   Start Station Id    85627 non-null  int64
#  3   Start Time          85627 non-null  object
#  4   Start Station Name  85326 non-null  object
#  5   End Station Id      85627 non-null  float64
#  6   End Time            85627 non-null  object
#  7   End Station Name    85331 non-null  object
#  8   Bike Id             85627 non-null  float64
#  9   User Type           85627 non-null  object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 7.2+ MB

# %% [markdown]
# ### Convert data type

# %% [markdown]
# Start and End time can be converted into date format for easier extraction and calculation later (this can also be done by string slicing, so the conversion is optional)

# %%
df01_v1['Start Time'] = pd.to_datetime(df01_v1['Start Time'])
df01_v1['End Time'] = pd.to_datetime(df01_v1['End Time'])

# %%
df01_v1.groupby(df01_v1['End Time'].dt.day_name()).count()
# Out:
#            Trip Id  Trip  Duration  Start Station Id  Start Time  \
# End Time
# Friday       13372           13372             13372       13372
# Monday       12225           12225             12225       12225
# Saturday     15533           15533             15533       15533
# Sunday       12268           12268             12268       12268
# Thursday     11922           11922             11922       11922
# Tuesday       9482            9482              9482        9482
# Wednesday    10825           10825             10825       10825
#
#            Start Station Name  End Station Id  End Time  End Station Name  \
# End Time
# Friday                  13318           13372     13372             13317
# Monday                  12185           12225     12225             12183
# Saturday                15481           15533     15533             15488
# Sunday                  12224           12268     12268             12227
# Thursday                11878           11922     11922             11877
# Tuesday                  9447            9482      9482              9445
# Wednesday               10793           10825     10825             10794
#
#            Bike Id  User Type
# End Time
# Friday       13372      13372
# Monday       12225      12225
# Saturday     15533      15533
# Sunday       12268      12268
# Thursday     11922      11922
# Tuesday       9482       9482
# Wednesday    10825      10825

# %% [markdown]
# All the IDs should be string

# %%
df01_v1['Trip Id'] = df01_v1['Trip Id'].astype("string")
df01_v1['Start Station Id'] = df01_v1['Start Station Id'].astype("string")
df01_v1['End Station Id'] = df01_v1['End Station Id'].astype("int")
df01_v1['End Station Id'] = df01_v1['End Station Id'].astype("string")
df01_v1['Bike Id'] = df01_v1['Bike Id'].astype("int")
df01_v1['Bike Id'] = df01_v1['Bike Id'].astype("string")

df01_v1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85627 entries, 0 to 86370
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Trip Id             85627 non-null  string
#  1   Trip  Duration      85627 non-null  int64
#  2   Start Station Id    85627 non-null  string
#  3   Start Time          85627 non-null  datetime64[ns]
#  4   Start Station Name  85326 non-null  object
#  5   End Station Id      85627 non-null  string
#  6   End Time            85627 non-null  datetime64[ns]
#  7   End Station Name    85331 non-null  object
#  8   Bike Id             85627 non-null  string
#  9   User Type           85627 non-null  object
# dtypes: datetime64[ns](2), int64(1), object(3), string(4)
# memory usage: 7.2+ MB

# %% [markdown]
# ## Calculate distance and average speed for each trip
#
# Not a very precise calcluation as users were not constantly cycling, but we can still use it as an indicator; for the records that reveal unusual patterns (such as trip duration over 24 hr), we'll discuss after the calculation.
#
# First, we need to load the geo info of each station

# %%
r = requests.get('https://tor.publicbikesystem.net/ube/gbfs/v1/en/station_information')

bikeshare_stations = pd.DataFrame(json.loads(r.content)['data']['stations'])[['station_id', 'name', 'lat', 'lon']].astype({
    'station_id': 'string',
})

bikeshare_stations
# Out:
#     station_id                          name        lat        lon
# 0         7000  Fort York  Blvd / Capreol Ct  43.639832 -79.395954
# 1         7001     Wellesley Station Green P  43.664964 -79.383550
# 2         7002    St. George St / Bloor St W  43.667333 -79.399429
# 3         7003      Madison Ave / Bloor St W  43.667158 -79.402761
# 4         7004       University Ave / Elm St  43.656518 -79.389099
# ..         ...                           ...        ...        ...
# 612       7686  Lower Jarvis / The Esplanade  43.647821 -79.370472
# 613       7687     Bloor / Gladstone - SMART  43.660202 -79.434273
# 614       7688  High Park Blvd / Parkside Dr  43.644887 -79.456412
# 615       7689                      20 Eaton  43.680012 -79.344033
# 616       7691       Christie St / Dupont St  43.671656 -79.420727
#
# [617 rows x 4 columns]

# %% [markdown]
# Back to the bike share trips, we define route with start and end station ID

# %%
df01_v1["routes"] = df01_v1["Start Station Id"].str.cat("-" + df01_v1["End Station Id"])

# %% [markdown]
# Extract the unique routes

# %%
routes = df01_v1[['Start Station Id', 'End Station Id', "routes"]].drop_duplicates()

# %% [markdown]
# Match start and end coordinates

# %%
routes = routes.merge(bikeshare_stations, how='inner', left_on='Start Station Id', right_on='station_id') \
       .merge(bikeshare_stations, how='inner', left_on='End Station Id', right_on='station_id', suffixes=['_start', '_end']) \
       .drop_duplicates()

# %% [markdown]
# Calculate distance (use the distance function in geopy)

# %%
routes['distance'] = routes.apply(lambda x: distance.distance((x['lat_start'], x['lon_start']), (x['lat_end'], x['lon_end'])).m, axis=1)

# %%
routes_count = df01_v1.groupby("routes")['Trip Id'].count()
routes_count = routes_count.reset_index()

# %%
routes = routes.merge(routes_count[['routes', 'Trip Id']], how='left', on='routes')
# Out:
#       Start Station Id End Station Id     routes station_id_start  \
# 0                 7021           7164  7021-7164             7021
# 1                 7006           7164  7006-7164             7006
# 2                 7014           7164  7014-7164             7014
# 3                 7053           7164  7053-7164             7053
# 4                 7257           7164  7257-7164             7257
# ...                ...            ...        ...              ...
# 34978             7625           7625  7625-7625             7625
# 34979             7613           7625  7613-7625             7613
# 34980             7622           7621  7622-7621             7622
# 34981             7621           7621  7621-7621             7621
# 34982             7614           7614  7614-7614             7614
#
#                                        name_start  lat_start  lon_start  \
# 0                              Bay St / Albert St  43.653264 -79.382458
# 1                 Bay St / College St (East Side)  43.660439 -79.385525
# 2      Sherbourne St / Carlton St (Allan Gardens)  43.663102 -79.373181
# 3                                Metro Hall Plaza  43.645859 -79.387830
# 4                    Dundas St W / St. Patrick St  43.654517 -79.389532
# ...                                           ...        ...        ...
# 34978                     Yonge St / Lawrence Ave  43.725467 -79.401154
# 34979        Livingston Rd (Highland Creek Trail)  43.756168 -79.202669
# 34980                           Marie Curtis Park  43.588077 -79.543207
# 34981                      Long Branch GO Station  43.591561 -79.545827
# 34982     Morningside Park (Highland Creek Trail)  43.779353 -79.193023
#
#       station_id_end                                  name_end    lat_end  \
# 0               7164  Gould St / Yonge St (Ryerson University)  43.657424
# 1               7164  Gould St / Yonge St (Ryerson University)  43.657424
# 2               7164  Gould St / Yonge St (Ryerson University)  43.657424
# 3               7164  Gould St / Yonge St (Ryerson University)  43.657424
# 4               7164  Gould St / Yonge St (Ryerson University)  43.657424
# ...              ...                                       ...        ...
# 34978           7625                   Yonge St / Lawrence Ave  43.725467
# 34979           7625                   Yonge St / Lawrence Ave  43.725467
# 34980           7621                    Long Branch GO Station  43.591561
# 34981           7621                    Long Branch GO Station  43.591561
# 34982           7614   Morningside Park (Highland Creek Trail)  43.779353
#
#          lon_end      distance  Trip Id
# 0     -79.381019    476.553315        1
# 1     -79.381019    494.293898        1
# 2     -79.381019    893.139950        2
# 3     -79.381019   1397.488587        1
# 4     -79.381019    758.834737        3
# ...          ...           ...      ...
# 34978 -79.401154      0.000000       13
# 34979 -79.401154  16348.698705        1
# 34980 -79.545827    441.111643        2
# 34981 -79.545827      0.000000        3
# 34982 -79.193023      0.000000        2
#
# [34983 rows x 13 columns]

# %%
routes = routes.rename({'Trip Id': 'Count'}, axis='columns')
# Out:
#       Start Station Id End Station Id     routes station_id_start  \
# 0                 7021           7164  7021-7164             7021
# 1                 7006           7164  7006-7164             7006
# 2                 7014           7164  7014-7164             7014
# 3                 7053           7164  7053-7164             7053
# 4                 7257           7164  7257-7164             7257
# ...                ...            ...        ...              ...
# 34978             7625           7625  7625-7625             7625
# 34979             7613           7625  7613-7625             7613
# 34980             7622           7621  7622-7621             7622
# 34981             7621           7621  7621-7621             7621
# 34982             7614           7614  7614-7614             7614
#
#                                        name_start  lat_start  lon_start  \
# 0                              Bay St / Albert St  43.653264 -79.382458
# 1                 Bay St / College St (East Side)  43.660439 -79.385525
# 2      Sherbourne St / Carlton St (Allan Gardens)  43.663102 -79.373181
# 3                                Metro Hall Plaza  43.645859 -79.387830
# 4                    Dundas St W / St. Patrick St  43.654517 -79.389532
# ...                                           ...        ...        ...
# 34978                     Yonge St / Lawrence Ave  43.725467 -79.401154
# 34979        Livingston Rd (Highland Creek Trail)  43.756168 -79.202669
# 34980                           Marie Curtis Park  43.588077 -79.543207
# 34981                      Long Branch GO Station  43.591561 -79.545827
# 34982     Morningside Park (Highland Creek Trail)  43.779353 -79.193023
#
#       station_id_end                                  name_end    lat_end  \
# 0               7164  Gould St / Yonge St (Ryerson University)  43.657424
# 1               7164  Gould St / Yonge St (Ryerson University)  43.657424
# 2               7164  Gould St / Yonge St (Ryerson University)  43.657424
# 3               7164  Gould St / Yonge St (Ryerson University)  43.657424
# 4               7164  Gould St / Yonge St (Ryerson University)  43.657424
# ...              ...                                       ...        ...
# 34978           7625                   Yonge St / Lawrence Ave  43.725467
# 34979           7625                   Yonge St / Lawrence Ave  43.725467
# 34980           7621                    Long Branch GO Station  43.591561
# 34981           7621                    Long Branch GO Station  43.591561
# 34982           7614   Morningside Park (Highland Creek Trail)  43.779353
#
#          lon_end      distance  Count
# 0     -79.381019    476.553315      1
# 1     -79.381019    494.293898      1
# 2     -79.381019    893.139950      2
# 3     -79.381019   1397.488587      1
# 4     -79.381019    758.834737      3
# ...          ...           ...    ...
# 34978 -79.401154      0.000000     13
# 34979 -79.401154  16348.698705      1
# 34980 -79.545827    441.111643      2
# 34981 -79.545827      0.000000      3
# 34982 -79.193023      0.000000      2
#
# [34983 rows x 13 columns]

# %%
routes["Count"].describe()
# Out:
# count    34983.000000
# mean         2.360404
# std          2.977792
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max        121.000000
# Name: Count, dtype: float64

# %% [markdown]
# Merge the distance calculation with the main DataFrame

# %%
df01_v2 = df01_v1.merge(routes[['routes', 'distance']], how='left', on='routes')
#df = df[[x for x in df.columns if not 'From' in x and not 'To' in x and x != 'Route Id']]
df01_v2
# Out:
#         Trip Id  Trip  Duration Start Station Id          Start Time  \
# 0      10644218            1315             7021 2021-01-01 00:04:00
# 1      10644220             396             7534 2021-01-01 00:07:00
# 2      10644221              86             7162 2021-01-01 00:10:00
# 3      10644222             741             7003 2021-01-01 00:10:00
# 4      10644223            2073             7562 2021-01-01 00:11:00
# ...         ...             ...              ...                 ...
# 85622  10748535             316             7059 2021-01-31 23:45:00
# 85623  10748536             158             7272 2021-01-31 23:45:00
# 85624  10748537            1245             7662 2021-01-31 23:46:00
# 85625  10748538             393             7409 2021-01-31 23:53:00
# 85626  10748539             961             7251 2021-01-31 23:55:00
#
#                                  Start Station Name End Station Id  \
# 0                                Bay St / Albert St           7164
# 1                           Walnut Ave / Queen St W           7524
# 2                          Hayter St / Laplante Ave           7006
# 3                          Madison Ave / Bloor St W           7272
# 4              Priscilla  Ave / Dundas St W - SMART           7562
# ...                                             ...            ...
# 85622                    Front St W / Blue Jays Way           7542
# 85623               Yonge St / Dundonald St - SMART           7044
# 85624                                           NaN           7259
# 85625                       Isabella St / Church St           7113
# 85626  The Royal Ontario Museum (Bloor St Entrance)           7046
#
#                  End Time                          End Station Name Bike Id  \
# 0     2021-01-01 00:26:00  Gould St / Yonge St (Ryerson University)    6795
# 1     2021-01-01 00:13:00                               Lisgar Park    4176
# 2     2021-01-01 00:11:00           Bay St / College St (East Side)    1814
# 3     2021-01-01 00:22:00           Yonge St / Dundonald St - SMART     198
# 4     2021-01-01 00:45:00      Priscilla  Ave / Dundas St W - SMART    6688
# ...                   ...                                       ...     ...
# 85622 2021-01-31 23:50:00                      Queen St W / John St    4531
# 85623 2021-01-31 23:48:00                  Church St / Alexander St    6681
# 85624 2021-02-01 00:07:00       Lower Spadina Ave / Lake Shore Blvd      96
# 85625 2021-01-31 23:59:00              Parliament St / Aberdeen Ave    6214
# 85626 2021-02-01 00:11:00                Niagara St / Richmond St W    5812
#
#            User Type     routes     distance
# 0      Annual Member  7021-7164   476.553315
# 1      Casual Member  7534-7524  1099.138396
# 2      Annual Member  7162-7006   141.384845
# 3      Casual Member  7003-7272  1456.774345
# 4      Casual Member  7562-7562     0.000000
# ...              ...        ...          ...
# 85622  Annual Member  7059-7542   736.672949
# 85623  Annual Member  7272-7044   430.766917
# 85624  Annual Member  7662-7259  3946.351009
# 85625  Casual Member  7409-7113  1180.602111
# 85626  Annual Member  7251-7046  2866.447111
#
# [85627 rows x 12 columns]

# %% [markdown]
# Calculate average speed (meters/second)

# %%
df01_v2["avg_speed"] = df01_v2["distance"]/ (df01_v2["Trip  Duration"])
df01_v2
# Out:
#         Trip Id  Trip  Duration Start Station Id          Start Time  \
# 0      10644218            1315             7021 2021-01-01 00:04:00
# 1      10644220             396             7534 2021-01-01 00:07:00
# 2      10644221              86             7162 2021-01-01 00:10:00
# 3      10644222             741             7003 2021-01-01 00:10:00
# 4      10644223            2073             7562 2021-01-01 00:11:00
# ...         ...             ...              ...                 ...
# 85622  10748535             316             7059 2021-01-31 23:45:00
# 85623  10748536             158             7272 2021-01-31 23:45:00
# 85624  10748537            1245             7662 2021-01-31 23:46:00
# 85625  10748538             393             7409 2021-01-31 23:53:00
# 85626  10748539             961             7251 2021-01-31 23:55:00
#
#                                  Start Station Name End Station Id  \
# 0                                Bay St / Albert St           7164
# 1                           Walnut Ave / Queen St W           7524
# 2                          Hayter St / Laplante Ave           7006
# 3                          Madison Ave / Bloor St W           7272
# 4              Priscilla  Ave / Dundas St W - SMART           7562
# ...                                             ...            ...
# 85622                    Front St W / Blue Jays Way           7542
# 85623               Yonge St / Dundonald St - SMART           7044
# 85624                                           NaN           7259
# 85625                       Isabella St / Church St           7113
# 85626  The Royal Ontario Museum (Bloor St Entrance)           7046
#
#                  End Time                          End Station Name Bike Id  \
# 0     2021-01-01 00:26:00  Gould St / Yonge St (Ryerson University)    6795
# 1     2021-01-01 00:13:00                               Lisgar Park    4176
# 2     2021-01-01 00:11:00           Bay St / College St (East Side)    1814
# 3     2021-01-01 00:22:00           Yonge St / Dundonald St - SMART     198
# 4     2021-01-01 00:45:00      Priscilla  Ave / Dundas St W - SMART    6688
# ...                   ...                                       ...     ...
# 85622 2021-01-31 23:50:00                      Queen St W / John St    4531
# 85623 2021-01-31 23:48:00                  Church St / Alexander St    6681
# 85624 2021-02-01 00:07:00       Lower Spadina Ave / Lake Shore Blvd      96
# 85625 2021-01-31 23:59:00              Parliament St / Aberdeen Ave    6214
# 85626 2021-02-01 00:11:00                Niagara St / Richmond St W    5812
#
#            User Type     routes     distance  avg_speed
# 0      Annual Member  7021-7164   476.553315   0.362398
# 1      Casual Member  7534-7524  1099.138396   2.775602
# 2      Annual Member  7162-7006   141.384845   1.644010
# 3      Casual Member  7003-7272  1456.774345   1.965957
# 4      Casual Member  7562-7562     0.000000   0.000000
# ...              ...        ...          ...        ...
# 85622  Annual Member  7059-7542   736.672949   2.331244
# 85623  Annual Member  7272-7044   430.766917   2.726373
# 85624  Annual Member  7662-7259  3946.351009   3.169760
# 85625  Casual Member  7409-7113  1180.602111   3.004077
# 85626  Annual Member  7251-7046  2866.447111   2.982775
#
# [85627 rows x 13 columns]

# %%
df01_v2["avg_speed"].describe()
# Out:
# count    82574.000000
# mean         5.232585
# std         58.197258
# min          0.000000
# 25%          1.906260
# 50%          2.568133
# 75%          3.167054
# max       3040.636202
# Name: avg_speed, dtype: float64

# %% [markdown]
# ## Special cases
#
# From data cleaning and calculation of routes and speed, we find some special cases:
#
# - **Same start and end station**
#
# Reasons could be the bike was not working and the user wanted to change one, or the user changed mind and shift to other transportation tools, etc. Such cases can be identified by short trip duration like 1 or 2 seconds.
#
# Or most likely, the user made a roundtrip. Therefore we can't make use of the distance and speed data, and we have to analyze such data separately.

# %%
df01_v2[df01_v2["distance"] == 0]
# Out:
#         Trip Id  Trip  Duration Start Station Id          Start Time  \
# 4      10644223            2073             7562 2021-01-01 00:11:00
# 25     10644246            1461             7164 2021-01-01 00:26:00
# 31     10644252             643             7448 2021-01-01 00:29:00
# 82     10644309             704             7519 2021-01-01 01:06:00
# 94     10644326             446             7037 2021-01-01 01:20:00
# ...         ...             ...              ...                 ...
# 85492  10748318             899             7375 2021-01-31 20:11:00
# 85494  10748320             498             7206 2021-01-31 20:12:00
# 85506  10748337             602             7035 2021-01-31 20:24:00
# 85514  10748349             516             7458 2021-01-31 20:30:00
# 85551  10748402            1121             7100 2021-01-31 21:16:00
#
#                              Start Station Name End Station Id  \
# 4          Priscilla  Ave / Dundas St W - SMART           7562
# 25     Gould St / Yonge St (Ryerson University)           7164
# 31     Goodwood Park Ct / Dentonia Park - SMART           7448
# 82           Sheridan Ave / Dundas St W - SMART           7519
# 94                    Bathurst St / Dundas St W           7037
# ...                                         ...            ...
# 85492                     Front St E / Scott St           7375
# 85494                Claremont St / Dundas St W           7206
# 85506                Queen St W / Ossington Ave           7035
# 85514                    Church St / Lombard St           7458
# 85551            Dundas St E / Regent Park Blvd           7100
#
#                  End Time                          End Station Name Bike Id  \
# 4     2021-01-01 00:45:00      Priscilla  Ave / Dundas St W - SMART    6688
# 25    2021-01-01 00:50:00  Gould St / Yonge St (Ryerson University)    6795
# 31    2021-01-01 00:40:00  Goodwood Park Ct / Dentonia Park - SMART    6316
# 82    2021-01-01 01:17:00        Sheridan Ave / Dundas St W - SMART    5875
# 94    2021-01-01 01:28:00                 Bathurst St / Dundas St W    2158
# ...                   ...                                       ...     ...
# 85492 2021-01-31 20:26:00                     Front St E / Scott St    4176
# 85494 2021-01-31 20:20:00                Claremont St / Dundas St W    4988
# 85506 2021-01-31 20:34:00                Queen St W / Ossington Ave    6447
# 85514 2021-01-31 20:39:00                    Church St / Lombard St    2488
# 85551 2021-01-31 21:34:00            Dundas St E / Regent Park Blvd    5094
#
#            User Type     routes  distance  avg_speed
# 4      Casual Member  7562-7562       0.0        0.0
# 25     Annual Member  7164-7164       0.0        0.0
# 31     Annual Member  7448-7448       0.0        0.0
# 82     Annual Member  7519-7519       0.0        0.0
# 94     Casual Member  7037-7037       0.0        0.0
# ...              ...        ...       ...        ...
# 85492  Annual Member  7375-7375       0.0        0.0
# 85494  Casual Member  7206-7206       0.0        0.0
# 85506  Annual Member  7035-7035       0.0        0.0
# 85514  Casual Member  7458-7458       0.0        0.0
# 85551  Annual Member  7100-7100       0.0        0.0
#
# [3272 rows x 13 columns]

# %% [markdown]
# - **Long distance within short time**
#
# Usually the cycling speed is around 10 m/s, and 50 m/s would be considered phenomenal. When we query the records with average speed above 30, the majority of their trip durations are 2. So such pattern might indicate system error.

# %%
df01_v2[(df01_v2["avg_speed"] > 30) & (df01_v2["Trip  Duration"] == 2)]
# Out:
#         Trip Id  Trip  Duration Start Station Id          Start Time  \
# 226    10644516               2             7168 2021-01-01 07:05:00
# 995    10645472               2             7109 2021-01-01 14:40:00
# 1463   10645994               2             7179 2021-01-01 16:49:00
# 1536   10646087               2             7327 2021-01-01 17:14:00
# 1947   10646760               2             7032 2021-01-02 10:37:00
# ...         ...             ...              ...                 ...
# 79339  10741055               2             7324 2021-01-28 18:29:00
# 79948  10741850               2             7026 2021-01-29 08:35:00
# 81741  10743917               2             7047 2021-01-29 22:19:00
# 81997  10744232               2             7177 2021-01-30 09:31:00
# 85468  10748289               2             7023 2021-01-31 19:51:00
#
#                                   Start Station Name End Station Id  \
# 226                           Queens Quay / Yonge St           7044
# 995                  Seaton St / Dundas St E - SMART           7389
# 1463   Bloor GO / UP Station (West Toronto Railpath)           7173
# 1536               Davenport Rd / Oakwood Rd - SMART           7419
# 1947                       Augusta Ave / Dundas St W           7551
# ...                                              ...            ...
# 79339                King St W / Charlotte St (West)           7505
# 79948                         Bay St / St. Joseph St           7162
# 81741      University Ave / Gerrard St W (East Side)           7158
# 81997                East Liberty St / Pirandello St           7451
# 85468                         College St / Borden St           7216
#
#                  End Time                            End Station Name Bike Id  \
# 226   2021-01-01 07:05:00                    Church St / Alexander St    6090
# 995   2021-01-01 14:40:00              College Park- Gerrard Entrance    6409
# 1463  2021-01-01 16:49:00                      Cariboo St / Rail Path    2441
# 1536  2021-01-01 17:14:00                       Bloor St W / Huron St    3157
# 1947  2021-01-02 10:37:00             The Esplanade / Hahn Pl - SMART    1981
# ...                   ...                                         ...     ...
# 79339 2021-01-28 18:29:00           Ontario St / Adelaide St E -SMART    6882
# 79948 2021-01-29 08:35:00                    Hayter St / Laplante Ave     205
# 81741 2021-01-29 22:19:00                     King St W / Stafford St    4069
# 81997 2021-01-30 09:31:00  Western Battery Rd / Pirandello St - SMART    6620
# 85468 2021-01-31 19:51:00               Wellington St W / Stafford St     746
#
#            User Type     routes     distance    avg_speed
# 226    Annual Member  7168-7044  2485.448622  1242.724311
# 995    Annual Member  7109-7389  1123.151179   561.575589
# 1463   Casual Member  7179-7173  1113.942251   556.971126
# 1536   Annual Member  7327-7419  2807.986568  1403.993284
# 1947   Annual Member  7032-7551  3022.549307  1511.274654
# ...              ...        ...          ...          ...
# 79339  Casual Member  7324-7505  2351.188138  1175.594069
# 79948  Annual Member  7026-7162   723.846652   361.923326
# 81741  Casual Member  7047-7158  2473.085200  1236.542600
# 81997  Annual Member  7177-7451   168.941036    84.470518
# 85468  Annual Member  7023-7216  1783.274610   891.637305
#
# [255 rows x 13 columns]

# %% [markdown]
# - **Long trip duration**
#
# There is a few trips that lasted for more than 12 hrs, so we may not consider the speed of these trips for relevant analysis.

# %%
df01_v2[df01_v2["Trip  Duration"] > 43200]
# Out:
#         Trip Id  Trip  Duration Start Station Id          Start Time  \
# 1327   10645828           81579             7569 2021-01-01 16:11:00
# 7933   10654134           72269             7023 2021-01-04 18:37:00
# 8480   10654733           48914             7069 2021-01-04 22:01:00
# 8604   10654879           44840             7046 2021-01-05 00:45:00
# 25099  10675339          146313             7207 2021-01-09 20:10:00
# 31059  10682427           80411             7148 2021-01-11 20:37:00
# 54720  10710857           57259             7450 2021-01-18 18:35:00
# 60736  10718437           62230             7160 2021-01-20 20:51:00
# 63982  10722544           59649             7336 2021-01-21 21:25:00
# 65399  10724406          199838             7226 2021-01-22 13:36:00
# 67512  10726702          101074             7311 2021-01-23 09:55:00
# 68905  10728222          169635             7027 2021-01-23 16:27:00
# 70334  10730025           87185             7102 2021-01-24 11:54:00
# 71240  10731000           70488             7354 2021-01-24 15:52:00
# 82129  10744385          106161             7113 2021-01-30 10:47:00
#
#                              Start Station Name End Station Id  \
# 1327                      Toronto Inukshuk Park           7473
# 7933                     College St / Borden St           7522
# 8480                   Queen St W / Spadina Ave           7000
# 8604                 Niagara St / Richmond St W           7329
# 25099                 Dundas St W / Crawford St           7153
# 31059               King St W / Joe Shuster Way           7633
# 54720         Carlaw Ave / Danforth Ave - SMART           7338
# 60736                  King St W / Tecumseth St           7524
# 63982                     Queen St E / Alton Av           7357
# 65399    Lake Shore Blvd W / The Boulevard Club           7222
# 67512               Sherbourne St / Isabella St           7357
# 68905                Beverley  St / Dundas St W           7267
# 70334                     Nelson St / Duncan St           7211
# 71240  Tommy Thompson Park (Leslie Street Spit)           7354
# 82129              Parliament St / Aberdeen Ave           7330
#
#                  End Time                          End Station Name Bike Id  \
# 1327  2021-01-02 14:51:00              Adelaide St W / Strachan Ave    5370
# 7933  2021-01-05 14:41:00         Wallace Ave / Pauline Ave - SMART     458
# 8480  2021-01-05 11:36:00              Fort York  Blvd / Capreol Ct    6259
# 8604  2021-01-05 13:12:00                  Crawford St / Queen St W    4886
# 25099 2021-01-11 12:48:00                  Bloor St W / Christie St    6040
# 31059 2021-01-12 18:57:00                     Noble St / Queen St W    5206
# 54720 2021-01-19 10:30:00                      Logan Ave / Bain Ave    1107
# 60736 2021-01-21 14:08:00                               Lisgar Park    4527
# 63982 2021-01-22 13:59:00             Lake Shore Blvd E / Leslie St     917
# 65399 2021-01-24 21:07:00                Sunnyside - Gus Ryder Pool    6345
# 67512 2021-01-24 14:00:00             Lake Shore Blvd E / Leslie St    4525
# 68905 2021-01-25 15:34:00         Dundas St E / Pembroke St - SMART    2076
# 70334 2021-01-25 12:07:00              Fort York Blvd / Garrison Rd    5317
# 71240 2021-01-25 11:27:00  Tommy Thompson Park (Leslie Street Spit)    6486
# 82129 2021-01-31 16:16:00                      Lee Ave / Queen St E    5669
#
#            User Type     routes     distance  avg_speed
# 1327   Casual Member  7569-7473  1222.964906   0.014991
# 7933   Annual Member  7023-7522  2833.953065   0.039214
# 8480   Annual Member  7069-7000  1035.582566   0.021171
# 8604   Casual Member  7046-7329   465.164928   0.010374
# 25099  Casual Member  7207-7153  1581.820624   0.010811
# 31059  Casual Member  7148-7633   590.088224   0.007338
# 54720  Casual Member  7450-7338   695.661418   0.012149
# 60736  Annual Member  7160-7524  1494.160649   0.024010
# 63982  Casual Member  7336-7357   533.080953   0.008937
# 65399  Annual Member  7226-7222   805.819961   0.004032
# 67512  Casual Member  7311-7357  3944.324024   0.039024
# 68905  Annual Member  7027-7267  1803.025483   0.010629
# 70334  Annual Member  7102-7211  1825.428520   0.020937
# 71240  Casual Member  7354-7354     0.000000   0.000000
# 82129  Casual Member  7113-7330  5712.562156   0.053810

# %% [markdown]
# ## Research questions
#
# After exploring the data, I came up with a few questions that the Bike Share Toronto and the public might be curious:
#
# - How many trips did poeple in Toronto had with Bike Share Toronto in 2021?
# - Was the ridership affected by season, weather, COVID-19, festivals and holidays, etc.?
# - What are the riders' behavior in terms of distance, speed, time of the day, day of the week, etc.?
# - What are the most popular cycling routes? Average speed on those routes? Any changes through the season?
# - Troubleshooting: which stations and bikes were frequently caught up in malfunctionings?
#
# With these questions in mind, we need functions to generate desirable datasets for each month in 2021.

# %%
def clean(df):
    df01 = df[df["Trip  Duration"] != 0]
    df01 = df01[df01["End Station Id"].notnull()]
    df01 = df01[df01["Bike Id"].notnull()]
    return df01

# %%
def conversion(df):
    df['Start Time'] = pd.to_datetime(df['Start Time'])
    df['End Time'] = pd.to_datetime(df['End Time'])
    df['Start Station Id'] = df['Start Station Id'].astype("string")
    df['End Station Id'] = df['End Station Id'].astype("int")
    df['End Station Id'] = df['End Station Id'].astype("string")
    df['Bike Id'] = df['Bike Id'].astype("int")
    df['Bike Id'] = df['Bike Id'].astype("string")
    return df

# %%
def calculate(df):
    df["routes"] = df["Start Station Id"].str.cat("-" + df["End Station Id"])
    
    routes = df[['Start Station Id', 'End Station Id', "routes"]].drop_duplicates()
    routes = routes.merge(bikeshare_stations, how='inner', left_on='Start Station Id', right_on='station_id') \
       .merge(bikeshare_stations, how='inner', left_on='End Station Id', right_on='station_id', suffixes=['_start', '_end']) \
       .drop_duplicates()
    routes['distance'] = routes.apply(lambda x: distance.distance((x['lat_start'], x['lon_start']), (x['lat_end'], x['lon_end'])).m, axis=1)
    
    df01 = df.merge(routes[['routes', 'distance']], how='left', on='routes')
    df01["avg_speed"] = df01["distance"]/ (df01["Trip  Duration"])
    df01 = df01[(df01["avg_speed"] < 30) & (df01["Trip  Duration"] != 2)]
    df01 = df01[df01["Trip  Duration"] < 43200]
    return df01

# %%
def process(input_file, output_file):
    df01 = pd.read_csv(input_file, encoding='cp1252')
    print(df01.shape)
    df01 = df01[df01["Trip  Duration"] != 0]
    df01 = df01[df01["End Station Id"].notnull()]
    df01 = df01[df01["Bike Id"].notnull()]
    #df01['Start Time'] = pd.to_datetime(df01['Start Time'])
    #df01['End Time'] = pd.to_datetime(df01['End Time'])
    #df01['Trip Id'] = df01['Trip Id'].astype("string")
    df01['Start Station Id'] = df01['Start Station Id'].astype("string")
    df01['End Station Id'] = df01['End Station Id'].astype("int")
    df01['End Station Id'] = df01['End Station Id'].astype("string")
    #df01['Bike Id'] = df01['Bike Id'].astype("int")
    #df01['Bike Id'] = df01['Bike Id'].astype("string")
    df01["routes"] = df01["Start Station Id"].str.cat("-" + df01["End Station Id"])
    
    routes = df01[['Start Station Id', 'End Station Id', "routes"]].drop_duplicates()
    routes = routes.merge(bikeshare_stations, how='inner', left_on='Start Station Id', right_on='station_id') \
       .merge(bikeshare_stations, how='inner', left_on='End Station Id', right_on='station_id', suffixes=['_start', '_end']) \
       .drop_duplicates()
    routes['distance'] = routes.apply(lambda x: distance.distance((x['lat_start'], x['lon_start']), (x['lat_end'], x['lon_end'])).m, axis=1)
    
    df02 = df01.merge(routes[['routes', 'distance']], how='left', on='routes')
    df02["avg_speed"] = df02["distance"]/ (df02["Trip  Duration"])
    df02 = df02[(df02["avg_speed"] < 30) & (df02["Trip  Duration"] != 2)]
    df02 = df02[df02["Trip  Duration"] < 43200]
    df02.to_csv(output_file)

# %%
#process("bike-share-ridership-2021-12.csv", "12_cleaned.csv")
